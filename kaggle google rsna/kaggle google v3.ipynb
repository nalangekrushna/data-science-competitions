# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv('./df.csv')

# %%
df.drop(columns=['sessionId','visitId'],inplace=True)

# %%
df.columns
# Out:
# Index(['channelGrouping', 'date', 'fullVisitorId', 'visitNumber',
#        'visitStartTime', 'browser', 'deviceCategory', 'isMobile',
#        'operatingSystem', 'city', 'continent', 'country', 'metro',
#        'networkDomain', 'region', 'subContinent', 'hits', 'pageviews',
#        'transactionRevenue', 'adContent', 'campaign', 'keyword', 'medium',
#        'referralPath', 'source'],
#       dtype='object')

# %%
df.channelGrouping.unique()
# Out:
# array(['Organic Search', 'Referral', 'Paid Search', 'Affiliates',
#        'Direct', 'Display', 'Social', '(Other)'], dtype=object)

# %%
df['transactionRevenue'].describe()
# Out:
# count    9.036530e+05
# mean     1.704273e+06
# std      5.277866e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.312950e+10
# Name: transactionRevenue, dtype: float64

# %%
import seaborn as sns
sns.distplot(df['transactionRevenue'],kde=False);

# %%
df.dropna(subset=['pageviews'],inplace=True)
df.drop(axis=1,columns=['referralPath','keyword','adContent'],inplace=True)

# %%
for i in range(df.shape[1]) :
    if(df[df.columns[i]].count() != 903653) :
        print(df[df.columns[i]].name)
        print(df[df.columns[i]].describe())
# Out:
# pageviews
# count    903553.000000
# mean          3.849764
# std           7.025274
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           4.000000
# max         469.000000
# Name: pageviews, dtype: float64
# adContent
# count                             10946
# unique                               44
# top       Google Merchandise Collection
# freq                               5122
# Name: adContent, dtype: object
# keyword
# count             400724
# unique              3659
# top       (not provided)
# freq              366363
# Name: keyword, dtype: object
# referralPath
# count     330941
# unique      1475
# top            /
# freq       75523
# Name: referralPath, dtype: object

# %%
#pd.set_option('display.max_rows',30)
df['source'].describe()
# Out:
# count     903653
# unique       380
# top       google
# freq      400788
# Name: source, dtype: object

# %% [markdown]
# looks like pagereviews is null so we are going to remove that rows.
# referralPath,keyword,adContent   removing column

# %%
df.drop(columns=['sessionId','visitId'],inplace=True)

# %%
df.columns
df.shape
# Out:
# Index(['channelGrouping', 'date', 'fullVisitorId', 'visitNumber',
#        'visitStartTime', 'browser', 'deviceCategory', 'isMobile',
#        'operatingSystem', 'city', 'continent', 'country', 'metro',
#        'networkDomain', 'region', 'subContinent', 'hits', 'pageviews',
#        'transactionRevenue', 'adContent', 'campaign', 'keyword', 'medium',
#        'referralPath', 'source'],
#       dtype='object')
# (903653, 25)

# %%
df.dropna(subset=['pageviews'],inplace=True)

# %%
df.drop(axis=1,columns=['referralPath','keyword','adContent'],inplace=True)

# %%
df.columns
# Out:
# Index(['channelGrouping', 'date', 'fullVisitorId', 'visitNumber',
#        'visitStartTime', 'browser', 'deviceCategory', 'isMobile',
#        'operatingSystem', 'city', 'continent', 'country', 'metro',
#        'networkDomain', 'region', 'subContinent', 'hits', 'pageviews',
#        'transactionRevenue', 'campaign', 'medium', 'source'],
#       dtype='object')

# %%
# plt.figure(figsize=(70,10))
# plt.scatter(df1['browser'], df1['transactionRevenue'])
# plt.xlabel("browser")
# plt.ylabel("transactionRevenue")
# #plt.axis[100,100]
# #plt.figure(figsize=(100,10), dpi=100)
# plt.show()
# Out:
# Text(0.5,0,'browser')
# Text(0,0.5,'transactionRevenue')

# %%
# plt.figure(figsize=(70,10))
# plt.scatter(df1['operatingSystem'], df1['transactionRevenue'])
# plt.xlabel("operatingSystem")
# plt.ylabel("transactionRevenue")
# plt.show()
# Out:
# Text(0.5,0,'operatingSystem')
# Text(0,0.5,'transactionRevenue')

# %%
# plt.scatter(df1['campaign'], df1['transactionRevenue'])
# plt.xlabel("campaign")
# plt.ylabel("transactionRevenue")
# plt.show()
# Out:
# Text(0.5,0,'campaign')
# Text(0,0.5,'transactionRevenue')

# %% [markdown]
# some findings.
# 1. only chrome firefox safari ie and edge opera generates revenue.(browsers)
# 2. only chrome os, ios, android, linux, mac, windows generates revenues.(os)
# 3.
